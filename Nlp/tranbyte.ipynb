# %%
0x60
# Out:
# 96

# %%
0x80
# Out:
# 128

# %%
0x60
# Out:
# 96

# %%
import json
import torch
import torch.nn as nn
from datasets import load_dataset

# %%
train_set = load_dataset("mwritescode/slither-audited-smart-contracts", 'big-multilabel', split='train', verification_mode='no_checks')
data = []
#只保留slither第一个标签
for i in range(len(train_set)):
    byte_info = dict()
    byte_info['bytecode'] = train_set[i]['bytecode']
    byte_info['slither'] = train_set[i]['slither'][0]
    data.append(byte_info)
    if i == 10:
        break
# Out:
# Using the latest cached version of the module from C:\Users\86177\.cache\huggingface\modules\datasets_modules\datasets\mwritescode--slither-audited-smart-contracts\4cf503b59ce9d3157914e47f6253de773b7ab828f46642685d4b470b88ca1f13 (last modified on Mon Mar 27 16:58:02 2023) since it couldn't be found locally at mwritescode/slither-audited-smart-contracts., or remotely on the Hugging Face Hub.
# Found cached dataset slither-audited-smart-contracts (C:/Users/86177/.cache/huggingface/datasets/mwritescode___slither-audited-smart-contracts/big-multilabel/1.1.0/4cf503b59ce9d3157914e47f6253de773b7ab828f46642685d4b470b88ca1f13)

# %%
bytecodes = [d['bytecode'] for d in data]
slithers = [d['slither'] for d in data]

# %%
bytecodes
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...']

# %%
slithers
# Out:
# [1, 1, 4, 4, 5, 4, 4, 4, 4, 4, 4]

# %%
for i in range(len(bytecodes)):
    bytecodes[i] = bytecodes[i][2:]  # 使用切片去掉前两个字符
print(bytecodes)
# Out:
# ['...', '...', '...', '...', '...', '...', '...', '...', '...', '...', '...']

# %%
#加前缀0x

prefixed_byte = ""

for byte in bytecodes:
    for i in range(0, len(byte), 2):
        prefixed_byte += '0x' + byte[i:i+2] + ","
    prefixed_byte += "\n"

print(prefixed_byte)
# Out:
# ,0x6
# ...

# %%
#简单数据的实验
byte=['608060405234801561001057600080fd5b50600436106102023','608060405234801561001057600080fd5b50600436106102024','608060405234801561001057600080fd5b50600436106102025']
#加前缀0x

prefixed_byte = ""

for i, b in enumerate(byte):
    for j in range(0, len(b), 2):
        if j+2 <= len(b):
            prefixed_byte += '0x' + b[j:j+2] + ''
        else:
            prefixed_byte += '0x' + b[j:j+2]
    if i != len(byte) - 1:
        prefixed_byte += '\n'
    
    

print(prefixed_byte)
# Out:
# 0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x3
# 0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x4
# 0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x5

# %%
prefixed_byte
# Out:
# ''

# %%
0x61
# Out:
# 97

# %%
byte_list =prefixed_byte.split('\n')  # split the string into a list of strings
print(byte_list)
byte_list[0]
# Out:
# ['0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x3', '0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x4', '0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x5']
# '0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x3'

# %%
# Out:
# ['0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x3', '0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x4', '0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x5']

# %%
decimal_list=[] #清空 不然可能会一直append

# %%
# decimal_list = []  # create an empty list to store the decimal values

# for byte in byte_list:
#     chunks = [byte[i:i+4] for i in range(0, len(byte), 4)]
#     decimal_chunks = [int(chunk, 16) for chunk in chunks]
#     decimal_list.extend(decimal_chunks)
#     decimal_list.append('\n')

# print(decimal_list)
#byte_list=['0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x3','0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x4','0x600x800x600x400x520x340x800x150x610x000x100x570x600x000x800xfd0x5b0x500x600x040x360x100x610x020x020x5']

for i in range(len(result)):
    for j in range(0, len(result[i]), 4):
        decimal_list.append(int(result[i][j:j+4] ,16))
    decimal_list.append('\n')
print(decimal_list)

# decimal_list = [int(byte_list[i][j:j+4], 16) for i in range(len(byte_list)) for j in range(0, len(byte_list[i]), 4)]

# print('/n'.join(map(str, decimal_list)))
# Out:
# [96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 3, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 4, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 5, '\n']

# %%
str(decimal_list)
# Out:
# "[96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 3, '\\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 4, '\\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 5, '\\n']"

# %%
new_list = [str(item) if item != '\n' else item for item in decimal_list]
new_list = [item.replace(',', ' ') if isinstance(item, int) else item for item in new_list]
new_list = [f"'{item}'" if isinstance(item, int) and new_list[i-1] == '\n' else item for i, item in enumerate(new_list)]
print(new_list)
# Out:
# ['96', '128', '96', '64', '82', '52', '128', '21', '97', '0', '16', '87', '96', '0', '128', '253', '91', '80', '96', '4', '54', '16', '97', '2', '2', '3', '\n', '96', '128', '96', '64', '82', '52', '128', '21', '97', '0', '16', '87', '96', '0', '128', '253', '91', '80', '96', '4', '54', '16', '97', '2', '2', '4', '\n', '96', '128', '96', '64', '82', '52', '128', '21', '97', '0', '16', '87', '96', '0', '128', '253', '91', '80', '96', '4', '54', '16', '97', '2', '2', '5', '\n']

# %%
new_list
# Out:
# ['96',
#  '128',
#  '96',
#  '64',
#  '82',
#  '52',
#  '128',
#  '21',
#  '97',
#  '0',
#  '16',
#  '87',
#  '96',
#  '0',
#  '128',
#  '253',
#  '91',
#  '80',
#  '96',
#  '4',
#  '54',
#  '16',
#  '97',
#  '2',
#  '2',
#  '3',
#  '\n',
#  '96',
#  '128',
#  '96',
#  '64',
#  '82',
#  '52',
#  '128',
#  '21',
#  '97',
#  '0',
#  '16',
#  '87',
#  '96',
#  '0',
#  '128',
#  '253',
#  '91',
#  '80',
#  '96',
#  '4',
#  '54',
#  '16',
#  '97',
#  '2',
#  '2',
#  '4',
#  '\n',
#  '96',
#  '128',
#  '96',
#  '64',
#  '82',
#  '52',
#  '128',
#  '21',
#  '97',
#  '0',
#  '16',
#  '87',
#  '96',
#  '0',
#  '128',
#  '253',
#  '91',
#  '80',
#  '96',
#  '4',
#  '54',
#  '16',
#  '97',
#  '2',
#  '2',
#  '5',
#  '\n']

# %%
slithers
# Out:
# [1, 1, 4, 4, 5, 4, 4, 4, 4, 4, 4]

# %%
decimal_list
# Out:
# [96,
#  128,
#  96,
#  64,
#  82,
#  52,
#  128,
#  21,
#  97,
#  0,
#  16,
#  87,
#  96,
#  0,
#  128,
#  253,
#  91,
#  80,
#  96,
#  4,
#  54,
#  16,
#  97,
#  2,
#  2,
#  3,
#  '\n',
#  96,
#  128,
#  96,
#  64,
#  82,
#  52,
#  128,
#  21,
#  97,
#  0,
#  16,
#  87,
#  96,
#  0,
#  128,
#  253,
#  91,
#  80,
#  96,
#  4,
#  54,
#  16,
#  97,
#  2,
#  2,
#  4,
#  '\n',
#  96,
#  128,
#  96,
#  64,
#  82,
#  52,
#  128,
#  21,
#  97,
#  0,
#  16,
#  87,
#  96,
#  0,
#  128,
#  253,
#  91,
#  80,
#  96,
#  4,
#  54,
#  16,
#  97,
#  2,
#  2,
#  5,
#  '\n']

# %%
result = "".join(str(decimal_list))  # 将处理好的列表拼接成字符串
print(result)
# Out:
# [96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 3, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 4, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 5, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 3, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 4, '\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 5, '\n']

# %%
result
# Out:
# "[96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 3, '\\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 4, '\\n', 96, 128, 96, 64, 82, 52, 128, 21, 97, 0, 16, 87, 96, 0, 128, 253, 91, 80, 96, 4, 54, 16, 97, 2, 2, 5, '\\n']"

# %%
# 将bytecodes和slithers列表中的值组合为一个字符串列表
lines = [f"{slither}\t{decimal}\n" for decimal, slither in zip(decimal_list, slithers)]

content=''.join(lines)
# 将字符串写入文件
with open('10jin.txt', 'w') as f:
    f.write(content)
